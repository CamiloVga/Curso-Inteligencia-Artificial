# %% [markdown]
# <a href="https://colab.research.google.com/github/CamiloVga/Curso-Inteligencia-Artificial/blob/main/Clase_TextoAVideo_CogVideoX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Instalar librerias
# !pip install --upgrade transformers accelerate diffusers imageio-ffmpeg
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 28.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.33.0
#     Uninstalling accelerate-0.33.0:
#       Successfully uninstalled accelerate-0.33.0
# ...

# %%
#importar y descargar el modelo
import torch
from diffusers import CogVideoXPipeline
from diffusers.utils import export_to_video

pipe = CogVideoXPipeline.from_pretrained(
    "THUDM/CogVideoX-2b",
    torch_dtype=torch.float16
)

pipe.enable_model_cpu_offload()
pipe.enable_sequential_cpu_offload()
pipe.vae.enable_slicing()
pipe.vae.enable_tiling()
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# model_index.json:   0%|          | 0.00/411 [00:00<?, ?B/s]
# Fetching 14 files:   0%|          | 0/14 [00:00<?, ?it/s]
# (…)ext_encoder/model.safetensors.index.json:   0%|          | 0.00/19.9k [00:00<?, ?B/s]
# text_encoder/config.json:   0%|          | 0.00/783 [00:00<?, ?B/s]
# scheduler/scheduler_config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# tokenizer/added_tokens.json:   0%|          | 0.00/2.59k [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.53G [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer/special_tokens_map.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# ...

# %%
#Inferencia

prompt = "A man running"

video = pipe(
    prompt=prompt,
    num_videos_per_prompt=1,
    num_inference_steps=20,
    num_frames=49,
    guidance_scale=6,
    generator=torch.Generator(device="cuda").manual_seed(42),
).frames[0]

export_to_video(video, "output1.mp4", fps=8)
